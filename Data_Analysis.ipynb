# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("./Cederman_Params_Nathaniel.csv", header=6, index_col='[run number]')

# %%
df.head()
# Out:
#               initial-resource-mean  victory-ratio  superiority-ratio  \
# [run number]
# 2                                50              2                2.0
# 1                                50              2                2.0
# 4                                50              2                2.0
# 3                                50              2                2.0
# 5                                50              2                2.0
#
#               harvest-std-dev  harvest-mean  proportion-predators  \
# [run number]
# 2                           5             2                  0.05
# 1                           5             2                  0.05
# 4                           5             2                  0.05
# 3                           5             2                  0.05
# 5                           5             2                  0.05
#
#               initial-resource-std-dev  [step]  count states  \
# [run number]
# ...

# %%
df = df.rename(index=str, columns={'[step]':'step', '[run number]': 'run number', 
           'count states with [count control-link-neighbors > 1]':'states > 1',
           'count states with [count control-link-neighbors > 2]':'states > 2' ,
           'count states with [count control-link-neighbors > 5]':'states > 5',  
           'count states with [count control-link-neighbors > 10]':'states > 10',  
           'count states with [count control-link-neighbors > 20]':'states > 20',  
           'count states with [count control-link-neighbors > 30]':'states > 30',      
          })
df
# Out:
#               initial-resource-mean  victory-ratio  superiority-ratio  \
# [run number]
# 2                                50              2                2.0
# 1                                50              2                2.0
# 4                                50              2                2.0
# 3                                50              2                2.0
# 5                                50              2                2.0
# 6                                50              2                2.0
# 7                                50              2                2.0
# 8                                50              2                2.0
# 9                                50              2                2.0
# 10                               50              2                2.0
# 11                               50              2                2.0
# 12                               50              2                2.0
# ...

# %%
cols = list(df.columns)
cols
# Out:
# ['initial-resource-mean',
#  'victory-ratio',
#  'superiority-ratio',
#  'harvest-std-dev',
#  'harvest-mean',
#  'proportion-predators',
#  'initial-resource-std-dev',
#  'step',
#  'count states',
#  'states > 1',
#  'states > 2',
#  'states > 5',
#  'states > 10',
#  'states > 20',
#  'states > 30']

# %%
df = df [['superiority-ratio', 'count states', 'proportion-predators',
 'states > 1',
 'states > 2',
 'states > 5',
 'states > 10',
 'states > 20',
 'states > 30']]

# %%
df
# Out:
#               superiority-ratio  count states  proportion-predators  \
# [run number]
# 2                           2.0            82                  0.05
# 1                           2.0            86                  0.05
# 4                           2.0            95                  0.05
# 3                           2.0            96                  0.05
# 5                           2.0            97                  0.05
# 6                           2.0            94                  0.05
# 7                           2.0            99                  0.05
# 8                           2.0            98                  0.05
# 9                           2.0            99                  0.05
# 10                          2.0            92                  0.05
# 11                          2.0            85                  0.05
# 12                          2.0            81                  0.05
# 14                          2.0            98                  0.05
# ...

# %%
g = sns.FacetGrid(df, col="superiority-ratio", sharex=True, sharey=True, xlim=(0, 1), ylim=(0,100), height=3)
g.map_dataframe(plt.scatter, x="proportion-predators", y='count states', alpha=.2).set_axis_labels(
    "Proportion Predators", "Remaining States")
plt.subplots_adjust(top=0.8)
g.fig.suptitle('Proportion Predators vs States Remaining at t=1000')
# Out:
# Text(0.5,0.98,'Proportion Predators vs States Remaining at t=1000')

# %%
df_2 = df.loc[ df['superiority-ratio']==2.0 ]['count states']
df_2
lst = []
for ()
df2 = df2.loc[df2['proportion-predators']==.05] 
df2
# Out:
# [run number]
# 2        82
# 1        86
# 4        95
# 3        96
# 5        97
# 6        94
# 7        99
# 8        98
# 9        99
# 10       92
# 11       85
# 12       81
# 14       98
# 13       99
# 15       98
# 16      100
# 17       97
# 18      100
# 19       93
# 20       61
# 21       92
# 22       98
# 23       91
# 24        2
# 26        9
# 25       57
# 27       91
# 28       88
# 29       36
# 30       81
#        ...
# 971      14
# 972      16
# 973      29
# 975      17
# 974      23
# 976      19
# 978      41
# 977      26
# 980      22
# 979      27
# 981      13
# 982      19
# 983      27
# 986      13
# 985      19
# 984      36
# 988      18
# 987      30
# 989      27
# 990      32
# 991      14
# 992      29
# 993      20
# 994      13
# 995      23
# 997      17
# 996      23
# 999      30
# 998      24
# 1000     22
# Name: count states, Length: 1000, dtype: int64

# %%
plt.hist(df2['count states'], histtype='barstacked', orientation='horizontal', stacked=True)
# Out:
# (array([ 2.,  0.,  0.,  1.,  0.,  1.,  2.,  1.,  8., 35.]),
#  array([  2. ,  11.8,  21.6,  31.4,  41.2,  51. ,  60.8,  70.6,  80.4,
#          90.2, 100. ]),
#  <a list of 10 Patch objects>)

# %%
for index, row in df.iterrows():
    print(row)
    print(type(row))
# Out:
# superiority-ratio     2.0
# count states         82.0
# states > 1            4.0
# states > 2            4.0
# states > 5            1.0
# states > 10           0.0
# states > 20           0.0
# states > 30           0.0
# Name: 2, dtype: float64
# <class 'pandas.core.series.Series'>
# superiority-ratio     2.0
# count states         86.0
# states > 1            4.0
# states > 2            4.0
# states > 5            1.0
# states > 10           0.0
# states > 20           0.0
# states > 30           0.0
# Name: 1, dtype: float64
# <class 'pandas.core.series.Series'>
# superiority-ratio     2.0
# count states         95.0
# states > 1            3.0
# states > 2            2.0
# states > 5            0.0
# states > 10           0.0
# states > 20           0.0
# states > 30           0.0
# Name: 4, dtype: float64
# <class 'pandas.core.series.Series'>
# superiority-ratio     2.0
# count states         96.0
# states > 1            3.0
# states > 2            1.0
# ...

# %%
sub_df = df.loc[df["superiority-ratio"] == 2.0]
base_dct = {'unipolar':0, 'bipolar':0, 'low multipolar':0, 'high multipolar':0, "little integration":0}
dct = {2.0:base_dct.copy(), 2.25:base_dct.copy(), 2.5:base_dct.copy(), 2.75:base_dct.copy(), 3.0:base_dct.copy()}
for index, row in df.iterrows():
    if (row['count states'] == 1):
        dct[row['superiority-ratio']]['unipolar'] = dct[row['superiority-ratio']]['unipolar']+1        
    elif (row['count states'] < 11):
        dct[row['superiority-ratio']]['bipolar'] = dct[row['superiority-ratio']]['bipolar'] +1
    elif (row['count states'] < 91):
        dct[row['superiority-ratio']]['high multipolar'] = dct[row['superiority-ratio']]['high multipolar'] +1
    elif (row['count states'] < 101):
        dct[row['superiority-ratio']]['little integration'] = dct[row['superiority-ratio']]['little integration'] +1

# %%
dct
# Out:
# {2.0: {'bipolar': 42,
#   'high multipolar': 889,
#   'little integration': 69,
#   'low multipolar': 0,
#   'unipolar': 0},
#  2.25: {'bipolar': 10,
#   'high multipolar': 859,
#   'little integration': 131,
#   'low multipolar': 0,
#   'unipolar': 0},
#  2.5: {'bipolar': 0,
#   'high multipolar': 725,
#   'little integration': 275,
#   'low multipolar': 0,
#   'unipolar': 0},
#  2.75: {'bipolar': 0,
#   'high multipolar': 458,
#   'little integration': 542,
#   'low multipolar': 0,
#   'unipolar': 0},
#  3.0: {'bipolar': 0,
#   'high multipolar': 211,
#   'little integration': 789,
#   'low multipolar': 0,
#   'unipolar': 0}}
